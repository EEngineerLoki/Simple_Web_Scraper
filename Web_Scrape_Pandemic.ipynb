# %%
import pandas as pd
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
html = urlopen('https://en.wikipedia.org/wiki/List_of_epidemics_and_pandemics')
bs = BeautifulSoup(html.read(), 'lxml')

# %%
url = pd.read_html('https://en.wikipedia.org/wiki/List_of_epidemics_and_pandemics')
data = url[0]
data
# Out:
#     Rank                 Epidemics/pandemics  \
# 0      1                         Spanish flu
# 1      2                 Plague of Justinian
# 2      3                   HIV/AIDS pandemic
# 3      4                         Black Death
# 4      5                   COVID-19 pandemic
# 5      6               Third plague pandemic
# 6      7    Cocoliztli epidemic of 1545–1548
# 7      8                     Antonine Plague
# 8      9       1520 Mexico smallpox epidemic
# 9     10    1918–1922 Russia typhus epidemic
# 10    11        1957–1958 influenza pandemic
# 11    12                       Hong Kong flu
# 12    13         Cocoliztli epidemic of 1576
# 13    14  735–737 Japanese smallpox epidemic
# 14    15            1772–1773 Persian Plague
# 15    16                       Naples Plague
# 16    17          1846–1860 cholera pandemic
# 17    18            1629–1631 Italian plague
# 18    19                  1889–1890 pandemic
#
# ...

# %%
data.info()
print(data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Rank                           19 non-null     int64
#  1   Epidemics/pandemics            19 non-null     object
#  2   Disease                        19 non-null     object
#  3   Death toll                     19 non-null     object
#  4   Percentage of population lost  19 non-null     object
#  5   Years                          19 non-null     object
#  6   Location                       19 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.2+ KB
# (19, 7)
